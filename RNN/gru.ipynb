# %%
import torch 
import torch.nn as nn
from torch.nn import functional as F

import sys
sys.path.append('..')
from d2l_helpers import *

# %%
batch_size, num_steps = 32, 35
train_iter, vocab = load_data_time_machine(batch_size, num_steps)

# %%
vocab_size, num_hiddens, device = len(vocab), 256, get_device()
num_epochs, lr = 500, 1

# %%
num_inputs = vocab_size
gru_layer = nn.GRU(num_inputs, num_hiddens)
model = RNNModel(gru_layer, vocab_size).to(device)
model = model.to(device)
train_rnn(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# time traveller t t a t a t a t a t a t a t a t a t a t a t a t a
# epoch 10, perplexity 15.8
# time travellere the the the the the the the the the the the the
# epoch 20, perplexity 12.4
# time travellere the the the the the the the the the the the the
# epoch 30, perplexity 10.7
# time travellere the the the the the the the the the the the the
# epoch 40, perplexity 10.0
# time travellerererererererererererererererererererererererererer
# epoch 50, perplexity 9.8
# time travellere the the the the the the the the the the the the
# epoch 60, perplexity 9.1
# time travellereat and and and and and and and and and and and an
# epoch 70, perplexity 9.0
# time traveller and the the the the the the the the the the the t
# epoch 80, perplexity 8.4
# time traveller the the the the the the the the the the the the t
# epoch 90, perplexity 8.2
# time traveller the the the the the the the the the the the the t
# epoch 100, perplexity 7.8
# time traveller and the the the the the the the the the the the t
# epoch 110, perplexity 7.5
# time traveller the the the the the the the the the the the the t
# epoch 120, perplexity 7.1
# time traveller and the the the the the the the the the the the t
# epoch 130, perplexity 6.8
# time traveller the the the the the the the the the the the the t
# epoch 140, perplexity 6.4
# time traveller the time traveller the the the the the the the th
# epoch 150, perplexity 6.2
# time traveller the time traveller the time traveller the time tr
# epoch 160, perplexity 5.8
# time traveller and the time traveller and the time traveller and
# epoch 170, perplexity 5.3
# time traveller a curiention ano he and the time traveller a curi
# epoch 180, perplexity 4.8
# time traveller the time traveller the time traveller the time tr
# epoch 190, perplexity 4.3
# time traveller the thing se man it in a conilation another thick
# epoch 200, perplexity 3.8
# time traveller the time traveller the time traveller the time tr
# epoch 210, perplexity 3.3
# time traveller three dimensions are werhay so have a seat ablets
# epoch 220, perplexity 2.8
# time travellericul unit the incanditees on the wird will peopee
# epoch 230, perplexity 2.4
# time traveller hem and so bugk of the whrle werhay mention on al
# epoch 240, perplexity 1.9
# time traveller filby but antwing his istine i tree thing seei th
# epoch 250, perplexity 1.8
# time travellericus and he sat it to us in thisway marking thas i
# epoch 260, perplexity 1.5
# time traveller for so it will be convenient to speak of himwas e
# epoch 270, perplexity 1.2
# time traveller from the beginnion another at sichour d her canno
# epoch 280, perplexity 1.2
# time travellericularsccuclycestith said the time travellerit s a
# epoch 290, perplexity 1.2
# time traveller ffreedbe comureable scall ofrect and if four dime
# epoch 300, perplexity 1.2
# time traveller ffreed frome time brightanien this is and the sai
# epoch 310, perplexity 1.2
# time traveller for so it will be convenient to speak of himwas e
# epoch 320, perplexity 1.1
# time traveller ffreedynom sciof discontwin therever of must you
# epoch 330, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 340, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 350, perplexity 1.1
# time travellericularsicufalline whing he took one of the small o
# epoch 360, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 370, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 380, perplexity 1.1
# time travelleryou can show black is white by argument said filby
# epoch 390, perplexity 1.1
# time travelleryou can show black is white by argument said filby
# epoch 400, perplexity 1.1
# time travelleryou can show black is white by argument said filby
# epoch 410, perplexity 1.0
# time traveller for so it will be convenient to speak of himwas e
# epoch 420, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 430, perplexity 1.1
# time traveller for so it will be convenient to speak of himwas e
# epoch 440, perplexity 1.1
# time travelleryou can show black is white by argument said filby
# epoch 450, perplexity 1.1
# time traveller with a slight accession ofcheerfulness really thi
# epoch 460, perplexity 1.1
# time travelleryou can show black is white by argument said filby
# epoch 470, perplexity 1.0
# time traveller for so it will be convenient to speak of himwas e
# epoch 480, perplexity 1.0
# time traveller for so it will be convenient to speak of himwas e
# epoch 490, perplexity 1.0
# time travelleryou can show black is white by argument said filby
# epoch 500, perplexity 1.0
# ppl: 1.0, 45274.7 token/s: mps
# time travelleryou can show black is white by argument said filby
# travelleryou can show black is white by argument said filby
